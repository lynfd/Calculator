# %%
import math

# %%
class calc():
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
        
    def addition(num1,num2):
        print(f'Addition= {num1+num2}')
    
    def subtraction(num1,num2):
        print(f'Subtraction= {num1-num2}')
    
    def multiplication(num1,num2):
        print(f'Multiplication= {num1*num2}')
        
    def division(num1,num2):
        print(f'Division= {num1/num2}')
    
    def floor(num1):
        print(f'Floor= {math.floor(num1)}')
    
    def ceiling(num1):
        print(f'Ceiling= {math.ceil(num1)}') 
    
    def maximum(num1,num2):
        print(f'Maximum= {max(num1,num2)}')
    
    def minimum(num1,num2):
        print(f'Minimum= {min(num1,num2)}')
    
    def squared(num1):
        print(f'Squared= {num1**2}')

    def cubed(num1):
        print(f'Cubed= {num1**3}')
    
    def exponent(num1,num2):
        print(f'Exponent={num1**num2}')
    
    def e(num1):
        print(f'Exponential Function={math.exp(num1)}')
    
    def squareroot(num1):
        print(f'Square Root= {math.sqrt(num1)}')
    
    def cuberoot(num1):
        print(f'Cubed Root= {num1**(1/3)}')
    
    def root(num1):
        print(f'Custom Root= {num1**(1/num2)}')
    
    
while True:        
    print('Chose from the following menu: ')
    print('1. Addition')
    print('2. Subtraction')
    print('3. Multiplication')
    print('4. Division')
    print('5. Floor')
    print('6. Ceiling')
    print('7. Max')
    print('8. Min')
    print('9. Square')
    print('10. Cubed')
    print('11. Exponent')
    print('12. e')
    print('13. Square Root')
    print('14. Cube root')
    print('15. Nth root')
    print('16. Quit')

    choice=int(input("Enter choice (1-16). "))

    if choice==1:
        num1=int(input("Enter first number: "))
        num2=int(input("Enter second number: "))
        calc.addition(num1,num2)
    elif choice==2:
        num1=int(input("Enter first number: "))
        num2=int(input("Enter second number: "))
        calc.subtraction(num1,num2)
    elif choice==3:
        num1=int(input("Enter first number: "))
        num2=int(input("Enter second number: "))
        calc.multiplication(num1,num2)
    elif choice==4:
        num1=int(input("Enter first number: "))
        num2=int(input("Enter second number: "))
        if num2==0:
            print("Not divisible by 0")
        else:
            calc.division(num1,num2)
    elif choice==5:
        num1=float(input("Enter a number: "))
        calc.floor(num1)
    elif choice==6:
        num1=float(input("Enter a number: "))
        calc.ceiling(num1)
    elif choice==7:
        num1=int(input("Enter first number: "))
        num2=int(input("Enter second number: "))
        calc.maximum(num1,num2)
    elif choice==8:
        num1=int(input("Enter first number: "))
        num2=int(input("Enter second number: "))
        calc.minimum(num1,num2)
    elif choice==9:
        num1=int(input("Enter a number: "))
        calc.squared(num1)
    elif choice==10:
        num1=int(input("Enter a number: "))
        calc.cubed(num1)
    elif choice==11:
        num1=int(input("Enter your base number: "))
        num2=int(input("Enter your exponent: "))
        calc.exponent(num1,num2)
    elif choice==12:
        num1=int(input("Enter a number: "))
        calc.e(num1)
    elif choice==13:
        num1=int(input("Enter a number: "))
        calc.squareroot(num1)
    elif choice==14:
        num1=int(input("Enter a number: "))
        calc.cuberoot(num1)
    elif choice==15:
        num1=int(input("Enter your base number: "))
        num2=int(input("Enter your Nth root: "))
        calc.root(num1)
    elif choice==16:
        break
    else:
        print("Not a valid input.")
# Out:
# Chose from the following menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Floor
# 6. Ceiling
# 7. Max
# 8. Min
# 9. Square
# 10. Cubed
# 11. Exponent
# 12. e
# 13. Square Root
# 14. Cube root
# 15. Nth root
# 16. Quit
